# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import functions as mf

# %%
from scipy.stats import norm, bartlett, ttest_ind, normaltest

# %%
df_notes = pd.read_csv('data\\notes.csv')

# %%
df_notes.head()
# Out:
#    is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0        True    171.81       104.86        104.95        4.52       2.89
# 1        True    171.67       103.74        103.70        4.01       2.87
# 2        True    171.83       103.76        103.76        4.40       2.88
# 3        True    171.80       103.78        103.65        3.73       3.12
# 4        True    172.05       103.70        103.75        5.04       2.27
#
#    length
# 0  112.83
# 1  113.29
# 2  113.84
# 3  113.63
# 4  113.55

# %%
# Mission 0
# Afin d'introduire votre analyse, effectuez une brève description des données (analyses univariées et bivariées).

# %%
df_notes.describe()
# Out:
#          diagonal  height_left  height_right  margin_low   margin_up  \
# count  170.000000   170.000000    170.000000  170.000000  170.000000
# mean   171.940588   104.066353    103.928118    4.612118    3.170412
# std      0.305768     0.298185      0.330980    0.702103    0.236361
# min    171.040000   103.230000    103.140000    3.540000    2.270000
# 25%    171.730000   103.842500    103.690000    4.050000    3.012500
# 50%    171.945000   104.055000    103.950000    4.450000    3.170000
# 75%    172.137500   104.287500    104.170000    5.127500    3.330000
# max    173.010000   104.860000    104.950000    6.280000    3.680000
#
#            length
# count  170.000000
# mean   112.570412
# std      0.924448
# min    109.970000
# 25%    111.855000
# 50%    112.845000
# 75%    113.287500
# max    113.980000

# %%
# 1. Vérification des valeurs nulles

# %%
df_notes.isnull().sum()
# Out:
# is_genuine      0
# diagonal        0
# height_left     0
# height_right    0
# margin_low      0
# margin_up       0
# length          0
# dtype: int64

# %%
df_result1 = pd.DataFrame(columns=['Variable', 'Moyenne','Mediane','Mode1'])

# %%
for i in range(1,len(df_notes.columns)):
        print(f'\n************{df_notes.columns[i]}***********')   

        print("moyenne : ",round(df_notes[df_notes.columns[i]].mean(),2))

        print("médiane :",df_notes[df_notes.columns[i]].median())
        print("mode :\n",df_notes[df_notes.columns[i]].mode())
        df_result1.loc[i] = [df_notes.columns[i],round(df_notes[df_notes.columns[i]].mean(),2),round(df_notes[df_notes.columns[i]].median(),2),df_notes[df_notes.columns[i]].mode()[0]]
        
df_result1
# Out:
# ************diagonal***********
# moyenne :  171.94
# médiane : 171.945
# mode :
#  0    172.1
# Name: diagonal, dtype: float64
#
# ************height_left***********
# moyenne :  104.07
# médiane : 104.055
# mode :
#  0    104.17
# 1    104.32
# Name: height_left, dtype: float64
#
# ************height_right***********
# moyenne :  103.93
# médiane : 103.95
# mode :
#  0    103.76
# 1    104.06
# Name: height_right, dtype: float64
#
# ************margin_low***********
# moyenne :  4.61
# médiane : 4.45
# mode :
#  0    3.97
# 1    4.08
# Name: margin_low, dtype: float64
#
# ************margin_up***********
# moyenne :  3.17
# médiane : 3.17
# mode :
#  0    3.07
# 1    3.24
# Name: margin_up, dtype: float64
#
# ************length***********
# moyenne :  112.57
# médiane : 112.845
# mode :
#  0    113.38
# Name: length, dtype: float64
#        Variable  Moyenne  Mediane   Mode1
# 1      diagonal   171.94   171.94  172.10
# 2   height_left   104.07   104.06  104.17
# ...

# %%
color_set2 = sns.color_palette("Set2")

# %%
#define plotting region (2 rows, 2 columns)
fig, axes = plt.subplots(2, 3,figsize=(15, 10))
# plt.gcf().subplots_adjust(left = 0.1, bottom = 0.1,
#                        right = 0.9, top = 0.9, wspace = 0, hspace = 0.5)

for i in range(1,len(df_notes.columns)):
    if (i<4):
#     axes[i-1].set_title(df_notes.columns[i])
#     sns.boxplot(data = df_notes[df_notes.columns[i]],orient="h",ax=axes[i-1] )
        sns.histplot(data=df_notes, x=df_notes.columns[i],ax=axes[0,i-1],color = color_set2[i-1] )
    else:
        sns.histplot(data=df_notes, x=df_notes.columns[i],ax=axes[1,i-4],color = color_set2[i-1]  )

# %%
 for i in range(1,len(df_notes.columns)):
#             print("-"*20,"catégorie : ",cat,"-"*20)
        print(f'\n************  {df_notes.columns[i]}  ***********')   
        print("variance empirique : ",df_notes[df_notes.columns[i]].var())
        print("variance empirique sans biais :",df_notes[df_notes.columns[i]].var(ddof=0))
        print("écart type empirique :\n",df_notes[df_notes.columns[i]].std())
        print("coefficient de la variation :",df_notes[df_notes.columns[i]].std(ddof=0))
# Out:
# ************  diagonal  ***********
# variance empirique :  0.09349432648799193
# variance empirique sans biais : 0.09294435986159198
# écart type empirique :
#  0.3057684197035265
# coefficient de la variation : 0.3048677743901313
#
# ************  height_left  ***********
# variance empirique :  0.08891443090845812
# variance empirique sans biais : 0.08839140484429073
# écart type empirique :
#  0.29818522919228935
# coefficient de la variation : 0.29730692027648925
#
# ************  height_right  ***********
# variance empirique :  0.10954791507135395
# variance empirique sans biais : 0.10890351557093421
# écart type empirique :
#  0.33098023365656437
# coefficient de la variation : 0.33000532657963905
#
# ************  margin_low  ***********
# variance empirique :  0.49294815175774465
# variance empirique sans biais : 0.490048456747405
# écart type empirique :
#  0.7021026646849766
# coefficient de la variation : 0.7000346111067688
#
# ************  margin_up  ***********
# ...

# %%
# 2. Boxplots des variables

# %%
#define plotting region (2 rows, 2 columns)
fig, axes = plt.subplots(6, 1,figsize=(10, 9))
plt.gcf().subplots_adjust(left = 0.1, bottom = 0.1,
                       right = 0.9, top = 0.9, wspace = 0, hspace = 0.5)

for i in range(1,len(df_notes.columns)):
    axes[i-1].set_title(df_notes.columns[i])
    sns.boxplot(data = df_notes[df_notes.columns[i]],orient="h",ax=axes[i-1],color=color_set2[i-1] )

# %%
sns.pairplot(data = df_notes.iloc[:,1:], palette = 'Set2' )

# %%
sns.pairplot(data=df_notes, hue='is_genuine')

# %%
# Diagramme en secteur

# %%
df_notes.describe()
# Out:
#          diagonal  height_left  height_right  margin_low   margin_up  \
# count  170.000000   170.000000    170.000000  170.000000  170.000000
# mean   171.940588   104.066353    103.928118    4.612118    3.170412
# std      0.305768     0.298185      0.330980    0.702103    0.236361
# min    171.040000   103.230000    103.140000    3.540000    2.270000
# 25%    171.730000   103.842500    103.690000    4.050000    3.012500
# 50%    171.945000   104.055000    103.950000    4.450000    3.170000
# 75%    172.137500   104.287500    104.170000    5.127500    3.330000
# max    173.010000   104.860000    104.950000    6.280000    3.680000
#
#            length
# count  170.000000
# mean   112.570412
# std      0.924448
# min    109.970000
# 25%    111.855000
# 50%    112.845000
# 75%    113.287500
# max    113.980000

# %%
df_notes["is_genuine"].value_counts()
# Out:
# True     100
# False     70
# Name: is_genuine, dtype: int64

# %%
fig = plt.figure(figsize=(7, 5))
df_notes["is_genuine"].value_counts(normalize=True).plot(kind='pie')
plt.axis('equal')
plt.title('Proprtion des classes', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Proprtion des classes')

# %%
variabes = df_notes.columns[1:]
df_notes.columns
# Out:
# Index(['is_genuine', 'diagonal', 'height_left', 'height_right', 'margin_low',
#        'margin_up', 'length'],
#       dtype='object')

# %%
fig, axes = plt.subplots(2, 3,figsize=(15, 10))

for i in range(1,len(df_notes.columns)):
    if (i<4):
#         sns.histplot(data=df_notes, x=df_notes.columns[i])
        sns.boxplot(x='is_genuine', y=df_notes.columns[i],data=df_notes, dodge=False,ax=axes[0,i-1],color = color_set2[i-1] )
    else:
#         sns.histplot(data=df_notes, x=df_notes.columns[i],ax=axes[1,i-4],color = color_set2[i-1]  )
        sns.boxplot(x='is_genuine', y=df_notes.columns[i],data=df_notes, dodge=False,ax=axes[1,i-4],color = color_set2[i-1] )

# %%
for i in range(1,len(df_notes.columns)):
    print(f'\n************  {df_notes.columns[i]}  ***********')  
    y1 = df_notes[df_notes.columns[i]].skew()
    print("Skewness empirique : ",y1)
    if (y1 == 0):
        print("--> Distribution symétrique")
    elif (y1 > 0):
        print("--> Distribution étalée à droite")
    else:
        print("Distribution étalée à gauche")
        
    y2 = df_notes[df_notes.columns[i]].kurtosis()
    print("kurtosis empirique : ",y2)
    if (y2 == 0):
        print("--> Même aplatissement que la distribution normale")
    elif (y2 > 0):
        print("--> moins aplatie que la distribution normale (observations plus concentrées)")
    else:
        print("--> plus aplatie que la distribution normale (observations moins concentrées)")
    
    print('\n*** Courbe de Lorenz ***')

    mf.courbe_lorenz(df_notes,df_notes.columns[i])
# Out:
# ************  diagonal  ***********
# Skewness empirique :  0.19616651211086614
# --> Distribution étalée à droite
# kurtosis empirique :  0.5868437884868345
# --> moins aplatie que la distribution normale (observations plus concentrées)
#
# *** Courbe de Lorenz ***
# gini = 0.00098926502133323
#
# ************  height_left  ***********
# Skewness empirique :  0.028648349767483303
# --> Distribution étalée à droite
# kurtosis empirique :  -0.461713483256764
# --> plus aplatie que la distribution normale (observations moins concentrées)
#
# *** Courbe de Lorenz ***
# gini = 0.0016290976983809324
#
# ************  height_right  ***********
# Skewness empirique :  0.16888595491251637
# --> Distribution étalée à droite
# kurtosis empirique :  -0.0048842800178983126
# --> plus aplatie que la distribution normale (observations moins concentrées)
#
# *** Courbe de Lorenz ***
# gini = 0.0017930612541421365
#
# ************  margin_low  ***********
# Skewness empirique :  0.5848587605714998
# ...

# %%
df_notes.iloc[:,1:].corr().style.background_gradient(cmap='RdBu_r').set_precision(3)
# Out:
# C:\Users\amina\AppData\Local\Temp\ipykernel_22804\1753054218.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df_notes.iloc[:,1:].corr().style.background_gradient(cmap='RdBu_r').set_precision(3)
# <style type="text/css">
# #T_72376_row0_col0, #T_72376_row1_col1, #T_72376_row2_col2, #T_72376_row3_col3, #T_72376_row4_col4, #T_72376_row5_col5 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_72376_row0_col1 {
#   background-color: #f8f1ed;
#   color: #000000;
# }
# #T_72376_row0_col2 {
#   background-color: #e4eef4;
#   color: #000000;
# }
# #T_72376_row0_col3 {
#   background-color: #81bad8;
#   color: #000000;
# }
# #T_72376_row0_col4 {
#   background-color: #a2cde3;
#   color: #000000;
# }
# #T_72376_row0_col5 {
#   background-color: #e0ecf3;
#   color: #000000;
# }
# #T_72376_row1_col0 {
#   background-color: #dae9f2;
#   color: #000000;
# }
# #T_72376_row1_col2, #T_72376_row2_col1 {
#   background-color: #d05548;
# ...

# %%
# df_notes.iloc[:,1:].corr().style.background_gradient(cmap='bwr').format(precision=3)

# %%
import seaborn as sns
corr = df_notes.iloc[:,1:].corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
# Out:
# <AxesSubplot:>

# %%
import scipy.stats as stats

# %%
stats.ttest_ind(df_notes['is_genuine'],df_notes['diagonal'])
# Out:
# Ttest_indResult(statistic=-3847.7606701353843, pvalue=0.0)

# %%
fig, axes = plt.subplots(2, 3,figsize=(15, 10))
for i in range(1, len(df_notes.columns)):

    if (i<4):
#     axes[i-1].set_title(df_notes.columns[i])
#     sns.boxplot(data = df_notes[df_notes.columns[i]],orient="h",ax=axes[i-1] )
        sns.distplot(df_notes[df_notes.columns[i]],ax=axes[0,i-1],color = color_set2[i-1],fit=norm, kde=False )
    else:
        sns.distplot(df_notes[df_notes.columns[i]],ax=axes[1,i-4],color = color_set2[i-1],fit=norm, kde=False  )
#         axes[i-1] = sns.distplot(df_notes[df_notes.columns[i]],  fit=norm, kde=False)
# Out:
# C:\Users\amina\anaconda3\envs\OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\amina\anaconda3\envs\OC\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
#define plotting region (2 rows, 2 columns)
fig, axes = plt.subplots(2, 3,figsize=(15, 10))
# plt.gcf().subplots_adjust(left = 0.1, bottom = 0.1,
#                        right = 0.9, top = 0.9, wspace = 0, hspace = 0.5)

for i in range(1,len(df_notes.columns)):
    if (i<4):
#     axes[i-1].set_title(df_notes.columns[i])
#     sns.boxplot(data = df_notes[df_notes.columns[i]],orient="h",ax=axes[i-1] )
        sns.histplot(data=df_notes, x=df_notes.columns[i],ax=axes[0,i-1],color = color_set2[i-1] )
    else:
        sns.histplot(data=df_notes, x=df_notes.columns[i],ax=axes[1,i-4],color = color_set2[i-1]  )

# %%
for i in ['diagonal', 'height_left', 'height_right', 'margin_low','margin_up', 'length'] :
    # Influence du genre sur l'acte d'achat
    table= pd.crosstab(df_notes[i],df_notes['is_genuine'])
    table.div(table.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
#     plt.title('Genre / Achat')
    plt.xlabel(i)
#     plt.ylabel('Pourcentage de client')

# %%
df_notes.iloc[:,1:].corr().style.background_gradient(cmap='RdBu_r').set_precision(3)
# Out:
# C:\Users\amina\AppData\Local\Temp\ipykernel_22804\1753054218.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df_notes.iloc[:,1:].corr().style.background_gradient(cmap='RdBu_r').set_precision(3)
# <style type="text/css">
# #T_55499_row0_col0, #T_55499_row1_col1, #T_55499_row2_col2, #T_55499_row3_col3, #T_55499_row4_col4, #T_55499_row5_col5 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_55499_row0_col1 {
#   background-color: #f8f1ed;
#   color: #000000;
# }
# #T_55499_row0_col2 {
#   background-color: #e4eef4;
#   color: #000000;
# }
# #T_55499_row0_col3 {
#   background-color: #81bad8;
#   color: #000000;
# }
# #T_55499_row0_col4 {
#   background-color: #a2cde3;
#   color: #000000;
# }
# #T_55499_row0_col5 {
#   background-color: #e0ecf3;
#   color: #000000;
# }
# #T_55499_row1_col0 {
#   background-color: #dae9f2;
#   color: #000000;
# }
# #T_55499_row1_col2, #T_55499_row2_col1 {
#   background-color: #d05548;
# ...

# %%
data = df_notes.drop(columns=['diagonal','height_left','height_right'])
data.corr().style.background_gradient(cmap='RdBu_r').set_precision(3)
# Out:
# C:\Users\amina\AppData\Local\Temp\ipykernel_22804\849315752.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   data.corr().style.background_gradient(cmap='RdBu_r').set_precision(3)
# <style type="text/css">
# #T_dcfc9_row0_col0, #T_dcfc9_row1_col1, #T_dcfc9_row2_col2, #T_dcfc9_row3_col3 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_dcfc9_row0_col1, #T_dcfc9_row0_col2, #T_dcfc9_row1_col0, #T_dcfc9_row1_col3 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_dcfc9_row0_col3 {
#   background-color: #b41c2d;
#   color: #f1f1f1;
# }
# #T_dcfc9_row1_col2 {
#   background-color: #edf2f5;
#   color: #000000;
# }
# #T_dcfc9_row2_col0 {
#   background-color: #276eb0;
#   color: #f1f1f1;
# }
# #T_dcfc9_row2_col1 {
#   background-color: #f9ebe3;
#   color: #000000;
# }
# #T_dcfc9_row2_col3 {
#   background-color: #185493;
#   color: #f1f1f1;
# }
# #T_dcfc9_row3_col0 {
#   background-color: #ae172a;
#   color: #f1f1f1;
# }
# ...
