# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Mission-n°-2" data-toc-modified-id="Mission-n°-2-1">Mission n° 2</a></span><ul class="toc-item"><li><span><a href="#Diagramme-en-secteurs-(catégorie)" data-toc-modified-id="Diagramme-en-secteurs-(catégorie)-1.1">Diagramme en secteurs (catégorie)</a></span></li><li><span><a href="#Diagramme-en-tuyaux-d'orgues" data-toc-modified-id="Diagramme-en-tuyaux-d'orgues-1.2">Diagramme en tuyaux d'orgues</a></span></li><li><span><a href="#Histogramme-de-prix" data-toc-modified-id="Histogramme-de-prix-1.3">Histogramme de prix</a></span></li><li><span><a href="#Mesure-de-tendance-central" data-toc-modified-id="Mesure-de-tendance-central-1.4">Mesure de tendance central</a></span><ul class="toc-item"><li><span><a href="#Le-mode" data-toc-modified-id="Le-mode-1.4.1">Le mode</a></span></li><li><span><a href="#La-moyenne" data-toc-modified-id="La-moyenne-1.4.2">La moyenne</a></span></li><li><span><a href="#La-médiane" data-toc-modified-id="La-médiane-1.4.3">La médiane</a></span></li><li><span><a href="#Mesures-de-tendance-central-selon-la-catégorie" data-toc-modified-id="Mesures-de-tendance-central-selon-la-catégorie-1.4.4">Mesures de tendance central selon la catégorie</a></span></li></ul></li><li><span><a href="#Mesure-de-dispersion-de-la-variable-'price'" data-toc-modified-id="Mesure-de-dispersion-de-la-variable-'price'-1.5">Mesure de dispersion de la variable 'price'</a></span><ul class="toc-item"><li><span><a href="#variance-empérique" data-toc-modified-id="variance-empérique-1.5.1">variance empérique</a></span></li><li><span><a href="#variance-empérique-sans-biais" data-toc-modified-id="variance-empérique-sans-biais-1.5.2">variance empérique sans biais</a></span></li><li><span><a href="#Ecart-type-empérique" data-toc-modified-id="Ecart-type-empérique-1.5.3">Ecart type empérique</a></span></li><li><span><a href="#Coefficient-de-la-variation" data-toc-modified-id="Coefficient-de-la-variation-1.5.4">Coefficient de la variation</a></span></li><li><span><a href="#Boite-à-moustache" data-toc-modified-id="Boite-à-moustache-1.5.5">Boite à moustache</a></span></li></ul></li><li><span><a href="#Mesures-de-dispersion-de-la-variable-'price'-selon-chaque-catégorie" data-toc-modified-id="Mesures-de-dispersion-de-la-variable-'price'-selon-chaque-catégorie-1.6">Mesures de dispersion de la variable 'price' selon chaque catégorie</a></span></li><li><span><a href="#Mesure-de-forme" data-toc-modified-id="Mesure-de-forme-1.7">Mesure de forme</a></span><ul class="toc-item"><li><span><a href="#Skewness-empérique" data-toc-modified-id="Skewness-empérique-1.7.1">Skewness empérique</a></span></li><li><span><a href="#kurtosis-empérique" data-toc-modified-id="kurtosis-empérique-1.7.2">kurtosis empérique</a></span></li><li><span><a href="#Courbe-de-Lorenz" data-toc-modified-id="Courbe-de-Lorenz-1.7.3">Courbe de Lorenz</a></span></li><li><span><a href="#Mesure-de-forme-pour-chaque-catégorie" data-toc-modified-id="Mesure-de-forme-pour-chaque-catégorie-1.7.4">Mesure de forme pour chaque catégorie</a></span></li><li><span><a href="#Représentation-de-série-temporelle" data-toc-modified-id="Représentation-de-série-temporelle-1.7.5">Représentation de série temporelle</a></span></li></ul></li><li><span><a href="#Suppression-du-mois-d'octobre-pour-toutes-les-catégories" data-toc-modified-id="Suppression-du-mois-d'octobre-pour-toutes-les-catégories-1.8">Suppression du mois d'octobre pour toutes les catégories</a></span></li><li><span><a href="#Suppression-du-mois-d'octobre-pour-la-catégorie-1" data-toc-modified-id="Suppression-du-mois-d'octobre-pour-la-catégorie-1-1.9">Suppression du mois d'octobre pour la catégorie 1</a></span></li></ul></li><li><span><a href="#Analyse-bivariée" data-toc-modified-id="Analyse-bivariée-2">Analyse bivariée</a></span><ul class="toc-item"><li><span><a href="#Avec-le-mois-d'octobre" data-toc-modified-id="Avec-le-mois-d'octobre-2.1">Avec le mois d'octobre</a></span></li><li><span><a href="#Sans-le-mois-d'octobre" data-toc-modified-id="Sans-le-mois-d'octobre-2.2">Sans le mois d'octobre</a></span></li></ul></li><li><span><a href="#Analyse-multivariée" data-toc-modified-id="Analyse-multivariée-3">Analyse multivariée</a></span><ul class="toc-item"><li><span><a href="#Avec-le-mois-d'octobre" data-toc-modified-id="Avec-le-mois-d'octobre-3.1">Avec le mois d'octobre</a></span></li><li><span><a href="#Sans-le-mois-d'octobre" data-toc-modified-id="Sans-le-mois-d'octobre-3.2">Sans le mois d'octobre</a></span></li></ul></li><li><span><a href="#Mission-n°-3" data-toc-modified-id="Mission-n°-3-4">Mission n° 3</a></span><ul class="toc-item"><li><span><a href="#1.-Corrélation-entre-le-sexe-des-clients-et-les-catégories-de-produits-achetés" data-toc-modified-id="1.-Corrélation-entre-le-sexe-des-clients-et-les-catégories-de-produits-achetés-4.1">1. Corrélation entre le sexe des clients et les catégories de produits achetés</a></span><ul class="toc-item"><li><span><a href="#Test-Khi2" data-toc-modified-id="Test-Khi2-4.1.1">Test Khi2</a></span></li></ul></li><li><span><a href="#2.-Corrélation-entre-l'âge-des-clients-et-le-montant-total-des-achats-:" data-toc-modified-id="2.-Corrélation-entre-l'âge-des-clients-et-le-montant-total-des-achats-:-4.2">2. Corrélation entre l'âge des clients et le montant total des achats :</a></span><ul class="toc-item"><li><span><a href="#Regression-linéaire" data-toc-modified-id="Regression-linéaire-4.2.1">Regression linéaire</a></span></li><li><span><a href="#Correlation-de-perason-et-covariance" data-toc-modified-id="Correlation-de-perason-et-covariance-4.2.2">Correlation de perason et covariance</a></span></li></ul></li><li><span><a href="#3.-Corrélation-entre-l'âge-des-clients-et-la-fréquence-d’achat-(ie.-nombre-d'achats-par-mois-par-exemple)" data-toc-modified-id="3.-Corrélation-entre-l'âge-des-clients-et-la-fréquence-d’achat-(ie.-nombre-d'achats-par-mois-par-exemple)-4.3">3. Corrélation entre l'âge des clients et la fréquence d’achat (ie. nombre d'achats par mois par exemple)</a></span><ul class="toc-item"><li><span><a href="#Test-Anova" data-toc-modified-id="Test-Anova-4.3.1">Test Anova</a></span></li></ul></li><li><span><a href="#4.-Corrélation-entre-l'âge-des-clients-et-la-taille-du-panier-moyen" data-toc-modified-id="4.-Corrélation-entre-l'âge-des-clients-et-la-taille-du-panier-moyen-4.4">4. Corrélation entre l'âge des clients et la taille du panier moyen</a></span><ul class="toc-item"><li><span><a href="#Test-Pearson" data-toc-modified-id="Test-Pearson-4.4.1">Test Pearson</a></span></li><li><span><a href="#Test-Anova" data-toc-modified-id="Test-Anova-4.4.2">Test Anova</a></span></li><li><span><a href="#Test-khi2" data-toc-modified-id="Test-khi2-4.4.3">Test khi2</a></span></li></ul></li><li><span><a href="#5.-Corrélation-entre-l'âge-des-clients-et-les-catégories-de-produits-achetés" data-toc-modified-id="5.-Corrélation-entre-l'âge-des-clients-et-les-catégories-de-produits-achetés-4.5">5. Corrélation entre l'âge des clients et les catégories de produits achetés</a></span><ul class="toc-item"><li><span><a href="#Test-Anova" data-toc-modified-id="Test-Anova-4.5.1">Test Anova</a></span></li><li><span><a href="#Test-Khi2" data-toc-modified-id="Test-Khi2-4.5.2">Test Khi2</a></span></li></ul></li></ul></li></ul></div>

# %%
# fig = plt.figure(figsize=(7, 5))
# fontsize=15
# plt.savefig('graphes\\pie_categorie.jpg')

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import scipy.stats as st
import numpy as np
import seaborn as sns

# %%
import P4_03_MyFunctions as mf

# %%
# Les données originales sans les valeurs testes
df_customers = pd.read_csv('new_data\\df_customers.csv')
df_products = pd.read_csv('new_data\\df_products.csv')
df_transactions = pd.read_csv('new_data\\df_transactions.csv')

# %%
# Jointure des 3 DF, sans valeurs test, en remplaçant le produit 
df_transaction_join = pd.read_csv('new_data\\df_transaction_join.csv', index_col = 'date' , parse_dates=True)

# %%
# SANS octobre pour cat 1, AVEC les 4 grands acheteurs 
data_1 = pd.read_csv('new_data\\data_1.csv', index_col = 'date' , parse_dates=True)
data_1 = data_1.sort_index()

# %%
# SANS octobre pour cat 1, cat2 et cat0, AVEC les 4 grands acheteurs 
data_2 = pd.read_csv('new_data\\data_2.csv', index_col = 'date' , parse_dates=True)
data_2 = data_2.sort_index()

# %%
# Sans octobre pour cat 1, SANS les 4 grands acheteurs 
data_1a = pd.read_csv('new_data\\data_1a.csv', index_col = 'date' , parse_dates=True)
data_1a = data_1a.sort_index()

# %%
# SANS octobre pour cat 1, cat2 et cat0, SANS les 4 grands acheteurs 
data_2b = pd.read_csv('new_data\\data_2b.csv', index_col = 'date' , parse_dates=True)
data_2b = data_2b.sort_index()

# %%
sns.lineplot(data=data_1a, x="month", y="number_purchase", hue="age_range")
# Out:
# <AxesSubplot:xlabel='month', ylabel='number_purchase'>

# %%
# df_transaction_join

# %% [markdown]
# # Mission n° 2
#
# Ensuite, vous réaliserez l’analyse des données. Une grande liberté vous est laissée sur ce plan, mais à vous de trouver les informations qui ont du sens pour mieux comprendre les ventes.
#
# Vous devrez y utiliser au moins :
#
# des indicateurs de tendance centrale et de dispersion ;
#
# une analyse de concentration, via une courbe de Lorenz et un indice de Gini ;
#
# des représentations graphiques, dont au moins un histogramme, une représentation avec des "boîtes à moustaches",
#
# et une représentation de série temporelle (c’est-à-dire un graphique dont l’axe des abscisses représente des dates) ;
# des analyses bivariées.

# %% [markdown]
# ## Diagramme en secteurs (catégorie)

# %%
fig = plt.figure(figsize=(7, 5))
df_products["categ"].value_counts(normalize=True).plot(kind='pie')
plt.axis('equal')
plt.title('Proprtion de chaque catégorie', fontsize=15)
plt.savefig('graphes\\pie_categorie.jpg')

# %% [markdown]
# ## Diagramme en tuyaux d'orgues

# %%
# Diagramme en tuyaux d'orgues
fig = plt.figure(figsize=(7, 5))
df_products["categ"].value_counts(normalize=True).plot(kind='bar')
plt.xlabel('Catégorie')
plt.ylabel('Fréquence')
plt.title('Fréquence de chaque catégorie', fontsize=15)
plt.savefig('graphes\\bar_categorie.jpg')
plt.show()

# %% [markdown]
# ## Histogramme de prix

# %%
# sturges_rule permet de définir le nombre de classes optimal
mf.sturges_rule(len(df_products['price']))
# Out:
# 13

# %%
# Histogramme  avec nombre de classes = 13
fig = plt.figure(figsize=(7, 5))
df_products["price"].hist(density=True,bins=13)
plt.title('Histogramme de prix des articles', fontsize=15)
plt.savefig('graphes\\histogramme_prix.jpg')
plt.show()

# %%
# Histogramme plus centralisé, avec nombre de classes = 13
fig = plt.figure(figsize=(7, 5))
plt.title('histogramme des prix inferieurs à 50',fontsize=15)
df_products[df_products.price <= 50]["price"].hist(density=True,bins=13)
plt.savefig('graphes\\histogramme_prix_mois_50.jpg')

# %% [markdown]
# ## Mesure de tendance central
# ### Le mode

# %%
df_products['price'].mode()
# Out:
# 0    4.99
# dtype: float64

# %% [markdown]
# ### La moyenne

# %%
df_products['price'].mean()
# Out:
# 21.860514146638216

# %% [markdown]
# ### La médiane

# %%
df_products['price'].median()
# Out:
# 13.06

# %% [markdown]
# ### Mesures de tendance central selon la catégorie

# %%
fig = plt.figure(figsize=(7, 5))

for cat in df_products["categ"].unique():
    subset = df_products.loc[df_products.categ == cat, :] # Création du sous-échantillon
    print("-"*20,"catégorie : ",cat,"-"*20)
    print("moyenne : ",subset['price'].mean())
    print("médiane :",subset['price'].median())
    print("mode :\n",subset['price'].mode())
    subset["price"].hist() # Crée l'histogramme
    plt.title(f'histogramme de prix pour catégorie {cat}',fontsize=15)
    plt.savefig(f'graphes\\histogramme_prix_cat_{cat}.jpg')
    plt.show() # Affiche l'histogramme
# Out:
# -------------------- catégorie :  0 --------------------
# moyenne :  11.732793417063943
# médiane : 10.32
# mode :
#  0    4.99
# dtype: float64
# -------------------- catégorie :  1 --------------------
# moyenne :  25.531420838971624
# médiane : 22.99
# mode :
#  0    22.99
# 1    32.99
# dtype: float64
# -------------------- catégorie :  2 --------------------
# moyenne :  108.35468619246883
# médiane : 101.99
# mode :
#  0    50.99
# 1    68.99
# 2    69.99
# dtype: float64

# %% [markdown]
# ## Mesure de dispersion de la variable 'price'

# %% [markdown]
# ### variance empérique

# %%
df_products['price'].var()
# Out:
# 890.7697899059915

# %% [markdown]
# ### variance empérique sans biais

# %%
df_products['price'].var(ddof=0)
# Out:
# 890.4987920995096

# %% [markdown]
# ### Ecart type empérique

# %%
df_products['price'].std()
# Out:
# 29.84576669991896

# %% [markdown]
# ### Coefficient de la variation

# %%
df_products['price'].std(ddof=0)
# Out:
# 29.84122638397272

# %% [markdown]
# ### Boite à moustache

# %%
fig = plt.figure(figsize=(7, 5))
df_products.boxplot(column ='price',vert=False)
plt.title('Boite à moustache du prix',fontsize=15)
plt.savefig('graphes\\boxplot_prix.jpg')

# %% [markdown]
# ## Mesures de dispersion de la variable 'price' selon chaque catégorie

# %%
for cat in df_products["categ"].unique():
    subset = df_products.loc[df_products.categ == cat, :] 
    print("-"*20,"catégorie : ",cat,"-"*20)
    print("variance empirique : ",subset['price'].var())
    print("variance empirique sans biais :",subset['price'].var(ddof=0))
    print("écart type empirique : ",subset['price'].std())
    print("coefficient de la variation :",subset['price'].std(ddof=0))
    subset.boxplot(column ='price',vert=False) 
    plt.title(f'Boite à moustache du prix pour catégorie {cat}',fontsize=15)
    plt.savefig(f'graphes\\boxplot_prix_cat{cat}.jpg')
    plt.show()
# Out:
# -------------------- catégorie :  0 --------------------
# variance empirique :  57.21584717610922
# variance empirique sans biais : 57.19106768404508
# écart type empirique :  7.56411575639276
# coefficient de la variation : 7.562477615440926
# -------------------- catégorie :  1 --------------------
# variance empirique :  237.93561274812913
# variance empirique sans biais : 237.61364304211
# écart type empirique :  15.42516167656369
# coefficient de la variation : 15.414721633623813
# -------------------- catégorie :  2 --------------------
# variance empirique :  2456.3354518969077
# variance empirique sans biais : 2446.0578977048704
# écart type empirique :  49.561431092099305
# coefficient de la variation : 49.45763740520639

# %% [markdown]
# ## Mesure de forme

# %% [markdown]
# ### Skewness empérique

# %%
df_products['price'].skew()
# Out:
# 3.7990837812619356

# %% [markdown]
# étalé à droite (ou oplique à gauche) <br/>
# Mode  < med < mean

# %% [markdown]
# ### kurtosis empérique

# %%
df_products['price'].kurtosis()
# Out:
# 17.95348596791864

# %% [markdown]
# ### Courbe de Lorenz

# %%
mf.courbe_lorenz(df_products,'price')
# Out:
# gini = 0.5316864283705149
# 0.5316864283705149

# %% [markdown]
# ### Mesure de forme pour chaque catégorie

# %%
for cat in df_products["categ"].unique():
    subset = df_products.loc[df_products.categ == cat, :] # Création du sous-échantillon
    print("-"*20,"catégorie : ",cat,"-"*20)
    y1 = subset['price'].skew()
    print("Skewness empérique : ",y1)
    if (y1 == 0):
        print("--> Distribution symétrique")
    elif (y1 > 0):
        print("--> Distribution étalée à droite")
    else:
        print("Distribution étalée à gauche")
        
    y2 = subset['price'].kurtosis()
    print("kurtosis empérique : ",y2)
    if (y2 == 0):
        print("--> Même aplatissement que la distribution normale")
    elif (y2 > 0):
        print("--> moins aplatie que la distribution normale (observations plus concentrées)")
    else:
        print("--> plus aplatie que la distribution normale (observations moins concentrées)")
    
    print('\n*** Courbe de Lorenz ***')

    mf.courbe_lorenz(subset,'price',cat)
# Out:
# -------------------- catégorie :  0 --------------------
# Skewness empérique :  0.8389029009262148
# --> Distribution étalée à droite
# kurtosis empérique :  0.33389251187387625
# --> moins aplatie que la distribution normale (observations plus concentrées)
#
# *** Courbe de Lorenz ***
# gini = 0.3574908993917699
# -------------------- catégorie :  1 --------------------
# Skewness empérique :  0.8120109621070365
# --> Distribution étalée à droite
# kurtosis empérique :  0.2993533794236898
# --> moins aplatie que la distribution normale (observations plus concentrées)
#
# *** Courbe de Lorenz ***
# gini = 0.3353482573943275
# -------------------- catégorie :  2 --------------------
# Skewness empérique :  0.9310209579538592
# --> Distribution étalée à droite
# kurtosis empérique :  0.808968484300689
# --> moins aplatie que la distribution normale (observations plus concentrées)
#
# *** Courbe de Lorenz ***
# gini = 0.2508340570212112

# %% [markdown]
# ### Représentation de série temporelle

# %%
# # Définir Date comme index 
# df_transaction_join['date'] = pd.to_datetime(df_transactions['date'], errors='coerce')
# df_transaction_join.set_index('date',inplace=True)
# df_transaction_join = df_transaction_join.sort_index()

# %%
# df_transaction_join.head()

# %%
fig = plt.figure(figsize=(7, 5))
df_transaction_join.resample('D')['price'].sum().plot()
plt.xlabel('Date')
plt.ylabel('chiffre d\'affaire')
plt.title('L\'évolution du chiffre d\'affaire dans le temps',fontsize=15)
plt.savefig('graphes\\chiffre_affaire_temps.jpg')

# %%
plt.figure(figsize=(7,5))
#regrouper le nombre de connexion par jour
df_transaction_join.resample('D')['session_id'].count().plot()
plt.xlabel('Date')
plt.ylabel('Nombre de session')
plt.title('L\'évolution du nombre de sessions dans le temps',fontsize=15)
plt.savefig('graphes\\nb_session_temps.jpg')
plt.show()

# %%
for cat in df_transaction_join["categ"].unique():
    subset = df_transaction_join.loc[df_transaction_join.categ == cat, :] # Création du sous-échantillon
    print("-"*20,"catégorie : ",cat,"-"*20)
    fig = plt.figure(figsize=(7, 5))
    plt.title(f'Chiffre d\'affaire pour la catégorie {cat}',fontsize=12)
    subset.resample('5D')['price'].sum().plot()
    plt.savefig(f'graphes\\chiffre_affaire_{cat}.jpg',transparent =True)
    plt.show()
# Out:
# -------------------- catégorie :  0 --------------------
# -------------------- catégorie :  2 --------------------
# -------------------- catégorie :  1 --------------------

# %%
fig = plt.figure(figsize=(7, 5))
df_transaction_join[(df_transaction_join["categ"]==1) & (df_transaction_join['month']==10)].resample('D')['price'].sum().plot()
plt.xlabel('jour')
plt.title('Chiffre d\'affaire du mois d\'octobre pour la catégorie 1')
plt.savefig('graphes\\chiffres_affaire_mois_octobre_cat_1')

# %% [markdown]
# ## Suppression du mois d'octobre pour toutes les catégories

# %%
for cat in data_2["categ"].unique():
    subset = data_2.loc[data_2.categ == cat, :] # Création du sous-échantillon
    print("-"*20,"catégorie : ",cat,"-"*20)
    fig = plt.figure(figsize=(7, 5))
    plt.title(f'Chiffre d\'affaire pour la catégorie {cat} - sans octobre',fontsize=12)
    subset.resample('5D')['price'].sum().plot()
    plt.savefig(f'graphes\\chiffre_affaire_{cat}.jpg')
    plt.show()
# Out:
# -------------------- catégorie :  0 --------------------
# -------------------- catégorie :  1 --------------------
# -------------------- catégorie :  2 --------------------

# %% [markdown]
# ## Suppression du mois d'octobre pour la catégorie 1

# %%
for cat in data_1["categ"].unique():
    subset = data_1.loc[data_1.categ == cat, :] # Création du sous-échantillon
    print("-"*20,"catégorie : ",cat,"-"*20)
    fig = plt.figure(figsize=(7, 5))
    if (cat==1):
        plt.title(f'Chiffre d\'affaire pour la catégorie {cat} - sans octobre',fontsize=12)
    else :
        plt.title(f'Chiffre d\'affaire pour la catégorie {cat} - avec octobre',fontsize=12)
    subset.resample('5D')['price'].sum().plot()
    plt.savefig(f'graphes\\chiffre_affaire_{cat}_data_1.jpg')
    plt.show()
# Out:
# -------------------- catégorie :  0 --------------------
# -------------------- catégorie :  1 --------------------
# -------------------- catégorie :  2 --------------------

# %% [markdown]
# # Analyse bivariée

# %% [markdown]
# ## Avec le mois d'octobre

# %%
fig = plt.figure(figsize=(7, 5))

ax = sns.boxplot(x="categ", y="price",   data=data_1, hue="categ", dodge=False).set_title('Boxplot du prix pour chaque catégorie (avec octobre)',fontsize=15)
plt.savefig('graphes\\boxplot_categorie_octobre.jpg')

# %% [markdown]
# pandas.qcut(x, q, labels=None, retbins=False, precision=3, duplicates='raise')
# pandas.cut(x, bins, right=True, labels=None, retbins=False, precision=3, include_lowest=False, duplicates='raise', ordered=True)

# %%
data_1[['categ','price']].corr()
# Out:
#           categ     price
# categ  1.000000  0.674412
# price  0.674412  1.000000

# %% [markdown]
# ## Sans le mois d'octobre

# %%
fig = plt.figure(figsize=(7, 5))
ax = sns.boxplot(x="categ", y="price",   data=data_2, hue="categ", dodge=False).set_title('Boxplot du prix pour chaque catégorie (sans octobre)',fontsize=15)
plt.savefig('graphes\\boxplot_categorie_sans_octobre.jpg')

# %% [markdown]
# # Analyse multivariée

# %% [markdown]
# ## Avec le mois d'octobre

# %%
fig = plt.figure(figsize=(9, 5))
ax = sns.barplot(x="age_range", y="price", hue="categ", data=data_1)
ax.set_xlabel('Age')
ax.set_title('Relation entre l\'âge du client et l\'argent dépensé (avec octobre)',fontsize = 14)
plt.savefig('graphes\\age_price_categ_avec_octobre.jpg')

# %% [markdown]
# ## Sans le mois d'octobre

# %%
fig = plt.figure(figsize=(9, 5))
ax = sns.barplot(x="age_range", y="price", hue="categ", data=data_2)
ax.set_xlabel('Age')
ax.set_title('Relation entre l\'âge du client et l\'argent dépensé (sans octobre)',fontsize=14)
plt.savefig('graphes\\age_price_categ_sans_octobre.jpg')

# %% [markdown]
# # Mission n° 3
# Voici quelques questions supplémentaires, que votre manager vous a posées :
#
# Y a-t-il une corrélation entre le sexe des clients et les catégories de produits achetés ?<br/>
# Y a-t-il une corrélation entre l'âge des clients et :<br/>
# Le montant total des achats ;<br/>
# La fréquence d’achat (ie. nombre d'achats par mois par exemple) ;<br/>
# La taille du panier moyen (en nombre d’articles) ;<br/>
# Les catégories de produits achetés.

# %% [markdown]
# ## 1. Corrélation entre le sexe des clients et les catégories de produits achetés

# %%
# Table de contingence frequences
cont_table_freq = pd.crosstab(data_1['sex'],data_1['categ'], normalize='index')
cont_table_freq
# Out:
# categ         0         1         2
# sex
# f      0.622716  0.327753  0.049531
# m      0.627620  0.317198  0.055182

# %%
# data_1[['categ','sex']].value_counts().plot(kind='bar')
cont_table_freq = pd.crosstab(data_1['categ'],data_1['sex'], normalize='all')
cont = cont_table_freq.reset_index()
cat=list(map(str, cont['categ'].to_list()))
nb_f = cont['f'].to_list()
nb_m = cont['m'].to_list()

# Position sur l'axe des x pour chaque étiquette
position = np.arange(len(cat))

# Largeur des barres
largeur = .35

# Création de la figure et d'un set de sous-graphiques
fig, ax = plt.subplots(figsize=(9,6))
r1 = ax.bar(position - largeur/2, nb_f, largeur,label="Femmes")
r2 = ax.bar(position + largeur/2, nb_m, largeur,label="Hommes")
print(fig)
print(ax)

# Modification des marques sur l'axe des x et de leurs étiquettes
ax.set_xticks(position)
ax.set_xticklabels(cat)
ax.set_ylabel('Fréquence d\'achat')
ax.set_xlabel('Catégorie')
ax.set_title("Fréquence d\'achat dans chaque catégorie selon le sexe", fontsize=14)
ax.legend()
plt.savefig('graphes\\bar_sexe_categorie_freq.jpg')
# Out:
# Figure(648x432)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
# # Table de contingence 
# cont_table = pd.crosstab(data_1['categ'],data_1['sex'])
# cont_table

# %%
# sns.heatmap(cont_table,annot=True)
# plt.show()

# %%
# Table de contingence 
cont_table = pd.crosstab(data_1['sex'],data_1['categ'])
cont_table
# Out:
# categ       0      1     2
# sex
# f      103846  54657  8260
# m      105683  53412  9292

# %%
plt.figure(figsize=(10,3))
ax = sns.heatmap(cont_table, annot=True)
ax.set_title('Carte de chaleur de entre catégorie et sexe')
plt.savefig('graphes\\heatmap_sexe_categorie.jpg')

# %% [markdown]
# ### Test Khi2
#
# hypothèse nulle H0 : On suppose que le sexe des clients ne dépends pas des catégories du produit acheté <br/>
#
# hypothèse à vérifier H1: Le sexe des clients dépend des catégories du produit acheté

# %%
st_chi2, st_p, st_dof, st_exp = st.chi2_contingency(cont_table , correction = True)

# Statistique khi2, 
print('st_chi2 =', st_chi2)
 
# Nombe de degrés de liberté
print('Degré de liberté =', st_dof)
 
# Pvalue : l'unique valeur nécessaire pour prendre notre décision
print('p-value = .2f',round(st_p,20))
# Out:
# st_chi2 = 83.25934590384985
# Degré de liberté = 2
# p-value = .2f 8.3e-19

# %%
# Test Khi2 selon l'axe 
st_chi2, st_p = st.chisquare(cont_table , ddof=0 , axis=0)

# Statistique khi2, 
print('st_chi2 =', st_chi2)
 
# Pvalue 
print(f'p-value = ',st_p)
# Out:
# st_chi2 = [16.10549852 14.3429198  60.67821331]
# p-value =  [5.99098399e-05 1.52351554e-04 6.72098771e-15]

# %%
# X = "sex"
# Y = "categ"

# cont = data_1[[X,Y]].pivot_table(index=X,columns=Y,aggfunc=len,margins=True,margins_name="Total")

# tx = cont.loc[:,["Total"]]
# ty = cont.loc[["Total"],:]
# n = len(data_1)
# indep = tx.dot(ty) / n

# c = cont.fillna(0) # On remplace les valeurs nulles par 0
# measure = (c-indep)**2/indep
# xi_n = measure.sum().sum()
# table = measure/xi_n
# sns.heatmap(table.iloc[:-1,:-1],annot=c.iloc[:-1,:-1])
# plt.show()

# %% [markdown]
# ## 2. Corrélation entre l'âge des clients et le montant total des achats :

# %%
plt.figure(figsize=(8,5))
plt.plot(data_1['age'],data_1['price_customer_purchase'],"o")
plt.xlabel('Age')
plt.ylabel('Montant d\'achat')
plt.title('Montant d\'achat en fonction de l\'age',fontsize=14)
plt.savefig('montant_achat_age')

# %% [markdown]
# Il y a Quatre outliers (C'est à dire quatre 'très grands acheteurs) :

# %%
data_1['price_customer_purchase'].describe()
# Out:
# count    335150.000000
# mean       9706.637208
# std       34195.565261
# min           4.150000
# 25%         564.150000
# 50%         959.200000
# 75%        1495.140000
# max      162007.340000
# Name: price_customer_purchase, dtype: float64

# %%
mf.courbe_lorenz(data_1,'price_customer_purchase')
# Out:
# gini = 0.87567598801324
# 0.87567598801324

# %%
data_1a['price_customer_purchase'].describe()
# Out:
# count    312080.000000
# mean        978.551472
# std         542.396385
# min           4.150000
# 25%         538.560000
# 50%         902.830000
# 75%        1354.680000
# max        2564.250000
# Name: price_customer_purchase, dtype: float64

# %%
mf.courbe_lorenz(data_1a,'price_customer_purchase','sans grands acheteurs')
# Out:
# gini = 0.3137589910538756
# 0.3137589910538756

# %%
plt.figure(figsize=(7,5))
plt.subplot(1, 2, 1)
plt.title('Boite à moustache du prix total d\'achat (avec Vs sans grands acheurs)')
data_1.boxplot(column ='price_customer_purchase')
plt.xlabel('Avec grands acheteurs')

plt.subplot(1, 2, 2)
data_1a.boxplot(column ='price_customer_purchase')
plt.xlabel('Sans grands acheteurs')

plt.savefig('graphes\\boxplot_outliers')

# %%
plt.figure(figsize=(9,6))
plt.plot(data_1a['age'],data_1a['price_customer_purchase'],"o")
plt.xlabel('Age')
plt.ylabel('Montant d\'achat')
plt.title('Montant d\'achat en fonction de l\'age sans les grands acheteurs',fontsize=14)
plt.savefig('achat_age_sans_outliers')

# %% [markdown]
# ### Regression linéaire

# %%
mf.regression_lineaire(data_1a, "price_customer_purchase", "age")
plt.title('Régression linéaire entre Montant d\'achat en fonction de l\'age sans les grands acheteurs', fontsize=14)
plt.savefig('achat_age_sans_outliers')

# %%
# sns.relplot(x="age", y="price_customer_purchase", data=data_1a)

# %% [markdown]
# ### Correlation de perason et covariance

# %%
print('Correlation de Pearson entre age et prix total d\'achat = ', st.pearsonr(data_1a["age"],data_1a["price_customer_purchase"])[0])
print('Covariance entre age et prix total d\'achat =', np.cov(data_1a["age"],data_1a["price_customer_purchase"],ddof=0)[1,0])
# Out:
# Correlation de Pearson entre age et prix total d'achat =  -0.21715165760212626
# Covariance entre age et prix total d'achat = -1623.39129524255

# %% [markdown]
# ## 3. Corrélation entre l'âge des clients et la fréquence d’achat (ie. nombre d'achats par mois par exemple)

# %%
# corr = freq_achat.corr()
# corr.style.background_gradient(cmap='coolwarm')

# %%
# df_tmp = data_1a[['client_id','month','price_range','number_purchase_month','number_purchase']]
# df_tmp.groupby(['price_range','month']).agg(['mean','sum'])

# %%
corr = data_2a[['age_range_mean', 'number_purchase_month', 'number_purchase']].corr()
corr.style.background_gradient(cmap='YlOrRd')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-bf0f65320441> in <module>
# ----> 1 corr = data_2a[['age_range_mean', 'number_purchase_month', 'number_purchase']].corr()
#       2 corr.style.background_gradient(cmap='YlOrRd')
#
# NameError: name 'data_2a' is not defined

# %%
# sns.lineplot(data=data_1a, x="month", y="number_purchase_month", hue="age_range")

# %%
# sns.lineplot(data=data_1a, x="month", y="number_purchase", hue="age_range")

# %%
# sns.lineplot(data=data_1a, x="month", y="number_purchase")

# %%
# sns.barplot(data=data_1a, x="age_range", y="number_purchase")

# %%
# eta_squared(data_1a[''])

# %%
# sns.lineplot(data=data_1a, x="month", y="number_purchase_month_age", hue="age_range")

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, sharey=True,figsize=(10,7))
sns.lineplot(data=data_1a, x="month", y="number_purchase_month", hue="age_range", ax=ax1)
ax1.set_title('Fréquence d\'achat selon la tranche d\'age - Avec octobre',fontsize = 12)
sns.lineplot(data=data_2b, x="month", y="number_purchase_month", hue="age_range", ax=ax2)
ax2.set_title('Fréquence d\'achat selon la tranche d\'age - Sans octobre',fontsize = 12)
fig.tight_layout()
plt.savefig('graphes\\number_purchase_month.jpg')

# %%
# fig, (ax1, ax2) = plt.subplots(ncols=2, sharey=True)
# sns.lineplot(data=data_1a, x="month", y="number_purchase_month_age", hue="age_range", ax=ax1)
# ax1.set_title('Sans le mois d\'octobre pour toutes les catégories ')
# sns.lineplot(data=data_2b, x="month", y="number_purchase_month_age", hue="age_range", ax=ax2)

# %%
# sns.barplot(x="age_range_mean", y="purchase_frequency",  data=data_1a)

# %%
# sns.barplot(x="age_range_mean", y="mean_purchase_age",  data=data_1a)

# %%
# data_1a['age_range_mean'].value_counts()

# %%
plt.figure(figsize = (9,5))
sns.barplot(data=data_1a, x="age_range", y="number_purchase_month")
plt.title("Fréquences d'achat en fonction de l'age", fontsize = 13)
plt.savefig('graphes\\freq_purchase_age.jpg')

# %% [markdown]
# ### Test Anova

# %%
mf.eta_squared(data_1a['age_range'], data_1a['number_purchase_month'])

# %% [markdown]
# ## 4. Corrélation entre l'âge des clients et la taille du panier moyen

# %% [markdown]
# ### Test Pearson

# %%
data_1a[['age','basket_size']].corr()

# %%
plt.figure(figsize=(7,5))
sns.lineplot(x="age", y="basket_size", data=data_1a)
plt.title('Taille du panier en fonction de l\'age', fontsize=12)
plt.savefig('graphes\\basket_size_age.jpg')

# %% [markdown]
# ### Test Anova

# %%
ax = sns.barplot(x="age_range", y="basket_size", data=data_1a)

# %%
mf.eta_squared(data_1a['age_range'],data_1a['basket_size'])

# %% [markdown]
# ### Test khi2

# %%
# Table de contingence 
cont_table = pd.crosstab(data_1a['basket_size_range'],data_1a['age_range'])
cont_table

# %%
plt.figure(figsize=(10,4))
ax = sns.heatmap(cont_table, annot=True)
ax.set_title('Carte de chaleur de entre taille du panier et tranche d\'age')
plt.savefig('graphes\\heatmap_basket_size_age.jpg')

# %% [markdown]
# ## 5. Corrélation entre l'âge des clients et les catégories de produits achetés

# %%
corr = data_1a[['categ', 'age']].corr()
corr.style.background_gradient(cmap='YlOrRd')

# %%
plt.figure(figsize=(10,5))
ax = sns.boxplot(x="categ", y="age",   data=data_1a, hue="categ", dodge=False).set_title('Boxplot de l\'age pour chaque catégorie')
plt.savefig('graphes\\boxplot_age_fig.jpg')

# %% [markdown]
# ### Test Anova

# %%
X = "categ" # qualitative
Y = "age" # quantitative
    
mf.eta_squared(data_1a[X],data_1a[Y])

# %% [markdown]
# ### Test Khi2

# %%
# Table de contingence 
cont_table = pd.crosstab(data_1a['categ'],data_1a['age_range'])
cont_table

# %%
plt.figure(figsize=(10,4))
ax = sns.heatmap(cont_table, annot=True)
ax.set_title('Carte de chaleur entre catégorie et tranche d\'age',fontsize=13)
plt.savefig('graphes\\heatmap_categ_age.jpg')
